# %%
import keras.models as models
from skimage.transform import resize
from skimage.io import imsave

import tensorflow as tf
from keras import backend as K

from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, AveragePooling3D, ZeroPadding3D
from keras.initializers import RandomNormal
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from keras.layers import Activation
from keras.layers import Dropout
from keras.layers import concatenate
from keras.models import Model

from keras.optimizers import Adam
from keras.regularizers import l2
from keras.utils import plot_model


import tensorflow_addons as tfa
from keras.callbacks import ModelCheckpoint, CSVLogger

import numpy as np
import os
from tqdm import tqdm
import nibabel as nib
import random
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    print(e)

print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# GPU is available

# %%
IMG_ROWS = 256
IMG_COLS = 256
IMG_DEPTH = 192

BASE_DIR = '/kaggle'
TRAIN_DATA_PATH = os.path.join(BASE_DIR, 'input', 'mri-brain-dataset', 'NFBS_MRI_SKULL') #Biias Corrected
TEST_DATA_PATH = os.path.join(BASE_DIR, 'input', 'mri-brain-dataset', 'NFBS_MRI_SKULL') #Bias Corrected

if not os.path.exists('/kaggle/working/Models'):
    os.mkdir('/kaggle/working/Models')

# %%
#Normalize images
def normalize(image):
    image = image.astype('float32')
    range = image.max() - image.min()
    image_min = image.min()
    return (image - image_min)*255/range

#Read an image from disk. Images are stored in nii.gz format
def read_image(img_path):
    image = nib.load(img_path).get_data()
    #image = normalize(image)
    return image

# Load data from disk
def load_data_from_disk(v):
    images_mask = None
    if v == 'Training':
        images, images_mask = read_images()
    else:
        images = read_test_images()
    return images, images_mask

#Sample n images 
def read_n_images(n=10, stripped=False):
    list_dirs = os.listdir(TRAIN_DATA_PATH)
    N = len(list_dirs)
    random.shuffle(list_dirs)
    images = np.zeros((n,IMG_ROWS, IMG_COLS, IMG_DEPTH), dtype=np.float32)
    image_masks = np.zeros((n,IMG_ROWS, IMG_COLS, IMG_DEPTH), dtype=np.float32)
    stripped_images = np.zeros((n,IMG_ROWS, IMG_COLS, IMG_DEPTH), dtype=np.float32)
    

    for i in tqdm(range(n)):
        dir = list_dirs[i]
        d_path = os.path.join(TRAIN_DATA_PATH, dir)
        if not os.path.isdir(d_path):
            continue

        files = os.listdir(d_path)
        for file in files:
            file_path = os.path.join(d_path, file)
            if file.find('brain') == -1:
                image = read_image(file_path)
                image = normalize(image)
            elif file.find('brainmask') != -1:
                image_mask = read_image(file_path)
            else:
                if stripped == True:
                    stripped_image = read_image(file_path)
        
        images[i] = image
        image_masks[i] = image_mask
        stripped_images[i] = stripped_image
    
    if stripped == True:
        return images, image_masks, stripped_images
    else:
        return images, image_masks
        

#Load MRI data from disk. Images are stored in nii.gz format
def read_images():
    list_dirs = os.listdir(TRAIN_DATA_PATH)
    N = len(list_dirs)
    images = np.zeros((N,IMG_ROWS, IMG_COLS, IMG_DEPTH), dtype=np.float32)
    image_masks = np.zeros((N,IMG_ROWS, IMG_COLS, IMG_DEPTH), dtype=np.float32)
    i = 0

    for dir in tqdm(list_dirs):
        d_path = os.path.join(TRAIN_DATA_PATH, dir)
        if not os.path.isdir(d_path):
            continue

        files = os.listdir(d_path)
        for file in files:
            file_path = os.path.join(d_path, file)
            if file.find('brain') == -1:
                image = read_image(file_path)
                image = normalize(image)
            elif file.find('brainmask') != -1:
                image_mask = read_image(file_path)
            else:
                pass
        images[i] = image
        image_masks[i] = image_mask
        i += 1

    return images, image_masks

#Load Test MRI data from disk. Images are stored in nii.gz format
def read_test_images():
    list_dirs = os.listdir(TEST_DATA_PATH)
    N = len(list_dirs)
    images = np.zeros((N,IMG_ROWS, IMG_COLS, IMG_DEPTH), dtype=np.float32)
    i = 0

    for dir in tqdm(list_dirs):
        d_path = os.path.join(TEST_DATA_PATH, dir)
        if not os.path.isdir(d_path):
            continue

        files = os.listdir(d_path)
        for file in files:
            file_path = os.path.join(d_path, file)
            if file.find('brain') == -1:
                image = read_image(file_path)
                image = normalize(image)

        images[i] = image
        i += 1

    return images

# %%
# %matplotlib inline
def display_images(image, image_mask, stripped_image):
    derived_image = image * image_mask
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize = (24, 6))
    ax1.imshow(image[image.shape[0]//2])
    ax1.set_title('Image')
    ax2.imshow(image_mask[image_mask.shape[0]//2])
    ax2.set_title('Mask')
    ax3.imshow(stripped_image[stripped_image.shape[0]//2])
    ax3.set_title('Skull Stripped Image')
    ax4.imshow(derived_image[derived_image.shape[0]//2])
    ax4.set_title('Derived Skull Stripped Image')
    plt.show()


n = 3
images, image_masks, stripped_images = read_n_images(n, stripped=True)

for i in range(n):
    display_images(images[i], image_masks[i], stripped_images[i])
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   # Remove the CWD from sys.path while we load stuff.
# 100%|██████████| 3/3 [00:07<00:00,  2.62s/it]

# %%
#Metric for Segmentation Similarity
def _dice_coefficient(y_true, y_pred):
    SMOOTH = 1.0
    y_true_flat = K.flatten(y_true)
    y_pred_flat = K.flatten(y_pred)
    intersection = K.sum(y_true_flat * y_pred_flat)
    return (2. * intersection + SMOOTH) / (K.sum(y_true_flat) + K.sum(y_pred_flat) + SMOOTH)

#Metric for Segmentation Similarity
def dice_coefficient(y_true, y_pred):
    SMOOTH = 1.0
    y_true_flat = K.flatten(y_true)
    y_pred_flat = K.flatten(y_pred)
    y_pred_flat = tf.cast(K.greater(y_pred_flat, 0.5), tf.float32)
    
    intersection = K.sum(y_true_flat*y_pred_flat)
    return (2. * intersection + SMOOTH) / (K.sum(y_true_flat) + K.sum(y_pred_flat) + SMOOTH)

# %%
#Create Training and Validation Generator
def get_generators(ratio=0.2, batch_size=8):
    list_dirs = os.listdir(TRAIN_DATA_PATH)
    N = len(list_dirs)
    random.shuffle(list_dirs)
    n_validation = (int)(N*0.2)
    n_train = N - n_validation

    train_generator = data_generator(list_dirs[0:n_train], batch_size,shuffle_data=True)
    validation_generator = data_generator(list_dirs[n_train:N], batch_size,shuffle_data=True)

    train_steps_epoch = n_train//batch_size
    if n_train%batch_size != 0:
        train_steps_epoch += 1

    validation_steps_epoch = n_validation//batch_size
    if n_validation%batch_size != 0:
        validation_steps_epoch += 1

    return train_generator, train_steps_epoch, validation_generator, validation_steps_epoch

#Create Generator
def data_generator(list_dirs, batch_size=8,shuffle_data=True):
    N = len(list_dirs)
    step_epoch = N//batch_size
    if N%batch_size != 0:
        step_epoch += 1

    while True:
        i = 0
        m = 0
        random.shuffle(list_dirs)

        while i < step_epoch:
            n = N - m
            if n >= batch_size:
                images = np.zeros((batch_size,IMG_ROWS, IMG_COLS, IMG_DEPTH), dtype=np.float32)
                image_masks = np.zeros((batch_size, IMG_ROWS, IMG_COLS, IMG_DEPTH), dtype=np.float32)
                delta_step = batch_size
            else:
                images = np.zeros((n, IMG_ROWS, IMG_COLS, IMG_DEPTH), dtype=np.float32)
                image_masks = np.zeros((n, IMG_ROWS, IMG_COLS, IMG_DEPTH), dtype=np.float32)
                delta_step = n

            k = 0
            while k < delta_step:
                dir = list_dirs[m]
                m += 1
                d_path = os.path.join(TRAIN_DATA_PATH, dir)
                files = os.listdir(d_path)
                for file in files:
                    file_path = os.path.join(d_path, file)
                    if file.find('brain') == -1:
                        image = read_image(file_path)
                        image = normalize(image)
                    elif file.find('brainmask') != -1:
                        image_mask = read_image(file_path)
                    else:
                        pass
                images[k] = image
                image_masks[k] = image_mask
                k += 1

            i += 1
            yield images, image_masks

            images = None
            images_mask = None

    yield np.zeros((0,0)), np.zeros((0,0))

# %%
#Emcoder Block
def encoder_block(input, filters, kernel_size, activation='relu', padding='same', pooling=True, batchnorm = True):
    init = RandomNormal(stddev=0.02)
    conv_1 = Conv2D(filters, (kernel_size, kernel_size), padding= padding,  kernel_initializer=init)(input)
    if batchnorm:
        g = BatchNormalization()(conv_1, training=True)

    g = LeakyReLU(alpha=0.2)(conv_1)
    concat_1 = concatenate([input, g], axis=3)
    conv_2 = Conv2D(filters, (kernel_size, kernel_size), padding= padding, kernel_initializer=init)(concat_1)

    if batchnorm:
        g = BatchNormalization()(conv_2, training=True)
   
    concat_2 = concatenate([input, g], axis=3)

    if pooling == True:
        output = MaxPooling2D(pool_size=(2, 2))(concat_2)
        g = LeakyReLU(alpha=0.2)(output)
        return  g, concat_2
    else:
        return concat_2


#Decoder Block
def decoder_block(input, encoded_block, filters, kernel_size_t, kernel_size, strides, activation='relu', padding='same', dropout = True):
    init = RandomNormal(stddev=0.02)
    conv_up_1 = Conv2DTranspose(filters, (kernel_size_t, kernel_size_t), strides=(strides, strides), padding=padding)(input)
    g = BatchNormalization()(conv_up_1)
    concat_1  = concatenate([g, encoded_block], axis=3)
    conv_1 = Conv2D(filters, (kernel_size, kernel_size), activation=activation, padding=padding, kernel_initializer=init)(concat_1)
    concat_2 = concatenate([concat_1, conv_1], axis=3)
    conv_2 = Conv2D(filters, (kernel_size, kernel_size), activation=activation, padding=padding, kernel_initializer=init)(concat_2)

    if dropout == True:
        g = Dropout(0.5)(conv_2, training=True)

    output = concatenate([concat_1, conv_2], axis=3)
    g = Activation('relu')(output)

    return g

# %%
#Create Model
def create_model(img_rows, img_cols):
    #inputs = Input((IMG_ROWS, IMG_COLS, 3))
    inputs = Input((IMG_ROWS, IMG_COLS, 192))

    encoded_block_11, encoded_block_12 = encoder_block(input=inputs, filters=32,  kernel_size=3, batchnorm=False)
    encoded_block_21, encoded_block_22 = encoder_block(input=encoded_block_11, filters=64,   kernel_size=3)
    encoded_block_31, encoded_block_32 = encoder_block(input=encoded_block_21, filters=128,  kernel_size=3)
    encoded_block_41, encoded_block_42 = encoder_block(input=encoded_block_31, filters=256,  kernel_size=3)
    encoded_block_51, encoded_block_52 = encoder_block(input=encoded_block_41, filters=512,  kernel_size=3)
    encoded_block_61, encoded_block_62 = encoder_block(input=encoded_block_51, filters=512,  kernel_size=3)
    encoded_block = encoder_block(input= encoded_block_61, filters=1024, kernel_size=3, pooling=False)

    encoded_block = Activation('relu')(encoded_block)

    decoded_block_6 = decoder_block(input=encoded_block,   encoded_block=encoded_block_62,filters=512, kernel_size_t=2, kernel_size=3, strides=2)
    decoded_block_5 = decoder_block(input=decoded_block_6, encoded_block=encoded_block_52,filters=512, kernel_size_t=2, kernel_size=3, strides=2)
    decoded_block_4 = decoder_block(input=decoded_block_5, encoded_block=encoded_block_42,filters=256, kernel_size_t=2, kernel_size=3, strides=2, dropout=False)
    decoded_block_3 = decoder_block(input=decoded_block_4, encoded_block=encoded_block_32,filters=128, kernel_size_t=2, kernel_size=3, strides=2, dropout=False)
    decoded_block_2 = decoder_block(input=decoded_block_3, encoded_block=encoded_block_22,filters=64,  kernel_size_t=2, kernel_size=3, strides=2, dropout=False)
    decoded_block   = decoder_block(input=decoded_block_2, encoded_block=encoded_block_12,filters=32,  kernel_size_t=2, kernel_size=3, strides=2, dropout=False)

    #output = Conv2D(192, (1, 1), activation='sigmoid')(decoded_block)
    output = Conv2D(192, (1, 1), activation='tanh')(decoded_block)

    model = Model(inputs=[inputs], outputs=[output])

    ##model.summary()
    """
    #plot_model(model, to_file='model.png')
    learning_rate = 0.001
    weight_decay = 0.0001
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )
    """
    optimizer= Adam(lr=0.0002, beta_1=0.5) #"adam"
    #model.compile(optimizer=optimizer,loss='binary_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=optimizer,loss='mae', metrics=[dice_coefficient])
    """
    model.compile(optimizer=Adam(lr=1e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.000000199),
                                                    loss='binary_crossentropy', metrics=['accuracy'])
    """
    return model

# %%
#Training using Data Generator
def create_model_train_with_generator():
    print('---------------------------------------------------')
    print('  Loading MRI Training Meta Data from Disk         ')
    print('---------------------------------------------------')

    train_generator, train_n_step_epoch, validation_generator, validation_n_step_epoch  = get_generators(ratio=0.2, batch_size=1)

    print('---------------------------------------------------')
    print('             Creating and Fitting Model            ')
    print('---------------------------------------------------')
    model = create_model(IMG_ROWS, IMG_COLS)
    model.summary()
    
    model_weight_path = os.path.join(BASE_DIR, 'working', 'Models', 'model_weights')
    if not os.path.exists(model_weight_path):
        os.mkdir(model_weight_path)
    model_checkpoint = ModelCheckpoint(os.path.join(model_weight_path, 'skull_stripping.h5'), monitor='val_loss', save_best_only=True)

    log_dir_path = os.path.join(BASE_DIR, 'working', 'Models','logs')
    if not os.path.exists(log_dir_path):
        os.mkdir(log_dir_path)

    logger = CSVLogger(os.path.join(log_dir_path,'skull_stripping.csv'), separator=',', append=True)
    print("Logging is created at %s" %(log_dir_path))
    model.fit_generator(train_generator, steps_per_epoch = train_n_step_epoch,
                            validation_data = validation_generator,
                            validation_steps = validation_n_step_epoch,epochs=100, verbose=1, shuffle=True,
                            callbacks=[model_checkpoint, logger])
    return model

# %%
#Load Model from Disk
def load_model_from_disk():
    model = create_model(IMG_ROWS, IMG_COLS)
    model_weight_path = os.path.join(BASE_DIR, 'working', 'Models', 'model_weights', 'skull_stripping.h5')
    assert(os.path.exists(model_weight_path) == True), "Model path doesn't exist!"
    model.load_weights(model_weight_path)

    return model

#Display Predicted MRI Images
# %matplotlib inline
from scipy.special import softmax
def display_predicted_images(image, true_stripped_image, predicted_image_mask):
    predicted_image_mask = softmax(predicted_image_mask) * predicted_image_mask#((predicted_image_mask + .1)/.2
    predicted_image = (image * (predicted_image_mask) + 1.)/2.
    #predicted_image_mask = softmax(predicted_image_mask) * predicted_image_mask#((predicted_image_mask + .1)/.2
     
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize = (24, 6))
    ax1.imshow(image[image.shape[0]//2])
    ax1.set_title('Image')
    ax2.imshow(predicted_image_mask[predicted_image_mask.shape[0]//2])
    ax2.set_title('Predicted Mask')
    ax3.imshow(true_stripped_image[true_stripped_image.shape[0]//2])
    ax3.set_title('True Skull Stripped Image')
    ax4.imshow(predicted_image[predicted_image.shape[0]//2])
    ax4.set_title('Predicted Skull Stripped Image')
    plt.show()



#Test Modeel with n random image samples using Dice Coefficient
def predict_random(n=25):
    print('---------------------------------------------------')
    print(' Loading MRI Test Data(Random) and Model from Disk ')
    print('---------------------------------------------------')
    images, image_masks, stripped_images =read_n_images(n, stripped=True)
    
    assert(images.shape[0]==n)
    
    model = load_model_from_disk()
    predicted_image_masks = model.predict(images)

    dice_coeffs = np.zeros((n))
    for i in range(n):
        dice_coeffs[i] = dice_coefficient(image_masks[i], predicted_image_masks[i])
        print('Dice Coefficient: %f' %(dice_coeffs[i]))
        display_predicted_images(images[i], stripped_images[i], predicted_image_masks[i])
        

    print("Mean Dice Coeff=%f, Std Dice Coeff=%f" %(np.mean(dice_coeffs), np.std(dice_coeffs)))

# %%
#Predict Mask on Test MRI data
def predict_test():
    print('---------------------------------------------------')
    print('       Loading MRI Test Data and Model from Disk   ')
    print('---------------------------------------------------')

    test_images, _ = load_data_from_disk(v="Test")
    model = load_model_from_disk()
    predicted_image_masks = model.predict(test_images)

    return predicted_image_masks

# %%
model = create_model_train_with_generator()
# Out:
# ---------------------------------------------------
#   Loading MRI Training Meta Data from Disk
# ---------------------------------------------------
# ---------------------------------------------------
#              Creating and Fitting Model
# ---------------------------------------------------
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 19 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 32) 55328       input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 32) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 224 0           input_1[0][0]
#                                                                  leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 224 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 128, 128, 224 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 64) 129088      leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128, 128, 64) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 288 0           leaky_re_lu_1[0][0]
#                                                                  leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 165952      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 288 0           leaky_re_lu_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 288)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64, 64, 288)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 128)  331904      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 416)  0           leaky_re_lu_3[0][0]
#                                                                  leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  479360      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 416)  0           leaky_re_lu_3[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 416)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 32, 32, 416)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 256)  958720      leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 256)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 672)  0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 256)  1548544     concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 672)  0           leaky_re_lu_5[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 672)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 16, 16, 672)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 512)  3097088     leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 16, 16, 512)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 1184) 0           leaky_re_lu_7[0][0]
#                                                                  leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 512)  5456384     concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 1184) 0           leaky_re_lu_7[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 1184)   0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 8, 8, 1184)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 512)    5456384     leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 8, 8, 512)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 8, 8, 1696)   0           leaky_re_lu_9[0][0]
#                                                                  leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 512)    7815680     concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 512)    2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 1696)   0           leaky_re_lu_9[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 1696)   0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 4, 4, 1696)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 1024)   15631360    leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 4, 4, 1024)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 4, 4, 2720)   0           leaky_re_lu_11[0][0]
#                                                                  leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 1024)   25068544    concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 1024)   4096        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 4, 4, 2720)   0           leaky_re_lu_11[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 4, 4, 2720)   0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 512)    5571072     activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 512)    2048        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 8, 8, 2208)   0           batch_normalization_12[0][0]
#                                                                  concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 512)    10174976    concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 8, 8, 2720)   0           concatenate_14[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 512)    12534272    concatenate_15[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 8, 8, 2720)   0           concatenate_14[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 8, 2720)   0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 512)  5571072     activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 512)  2048        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 16, 16, 1696) 0           batch_normalization_13[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 512)  7815680     concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 16, 16, 2208) 0           concatenate_17[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 512)  10174976    concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 16, 16, 2208) 0           concatenate_17[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 2208) 0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 256)  2261248     activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 256)  1024        conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 32, 32, 928)  0           batch_normalization_14[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 256)  2138368     concatenate_20[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 32, 32, 1184) 0           concatenate_20[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 256)  2728192     concatenate_21[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 32, 32, 1184) 0           concatenate_20[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 1184) 0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 128)  606336      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 128)  512         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 64, 64, 544)  0           batch_normalization_15[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 128)  626816      concatenate_23[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 64, 64, 672)  0           concatenate_23[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 128)  774272      concatenate_24[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 64, 64, 672)  0           concatenate_23[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 672)  0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 64) 172096      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 64) 256         conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 128, 128, 352 0           batch_normalization_16[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 64) 202816      concatenate_26[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 128, 128, 416 0           concatenate_26[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 64) 239680      concatenate_27[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 128, 128, 416 0           concatenate_26[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 416 0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 256, 256, 32) 53280       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 256, 32) 128         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 256, 256, 256 0           batch_normalization_17[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 256, 256, 32) 73760       concatenate_29[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 256, 256, 288 0           concatenate_29[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 32) 82976       concatenate_30[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 256, 256, 288 0           concatenate_29[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256, 256, 288 0           concatenate_31[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 192 55488       activation_6[0][0]
# ==================================================================================================
# Total params: 128,067,712
# Trainable params: 128,059,712
# Non-trainable params: 8,000
# __________________________________________________________________________________________________
# Logging is created at /kaggle/working/Models/logs
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   # Remove the CWD from sys.path while we load stuff.
# Epoch 1/100
# 100/100 [==============================] - 238s 2s/step - loss: 0.6512 - dice_coefficient: 0.2969 - val_loss: 0.5789 - val_dice_coefficient: 0.3429
# Epoch 2/100
# 100/100 [==============================] - 165s 2s/step - loss: 0.5695 - dice_coefficient: 0.3578 - val_loss: 0.5583 - val_dice_coefficient: 0.3629
# Epoch 3/100
# 100/100 [==============================] - 136s 1s/step - loss: 0.5448 - dice_coefficient: 0.3776 - val_loss: 0.5359 - val_dice_coefficient: 0.3809
# Epoch 4/100
# 100/100 [==============================] - 119s 1s/step - loss: 0.5228 - dice_coefficient: 0.3972 - val_loss: 0.5210 - val_dice_coefficient: 0.4143
# Epoch 5/100
# 100/100 [==============================] - 117s 1s/step - loss: 0.5039 - dice_coefficient: 0.4155 - val_loss: 0.5027 - val_dice_coefficient: 0.4099
# Epoch 6/100
# 100/100 [==============================] - 123s 1s/step - loss: 0.4822 - dice_coefficient: 0.4332 - val_loss: 0.4808 - val_dice_coefficient: 0.4232
# Epoch 7/100
# 100/100 [==============================] - 124s 1s/step - loss: 0.4661 - dice_coefficient: 0.4433 - val_loss: 0.4589 - val_dice_coefficient: 0.4233
# Epoch 8/100
# 100/100 [==============================] - 121s 1s/step - loss: 0.4434 - dice_coefficient: 0.4534 - val_loss: 0.4350 - val_dice_coefficient: 0.4584
# Epoch 9/100
# 100/100 [==============================] - 121s 1s/step - loss: 0.4179 - dice_coefficient: 0.4713 - val_loss: 0.4201 - val_dice_coefficient: 0.4684
# Epoch 10/100
# 100/100 [==============================] - 134s 1s/step - loss: 0.4011 - dice_coefficient: 0.4831 - val_loss: 0.4082 - val_dice_coefficient: 0.4718
# Epoch 11/100
# 100/100 [==============================] - 132s 1s/step - loss: 0.3860 - dice_coefficient: 0.4894 - val_loss: 0.3817 - val_dice_coefficient: 0.5072
# Epoch 12/100
# 100/100 [==============================] - 126s 1s/step - loss: 0.3676 - dice_coefficient: 0.5013 - val_loss: 0.3689 - val_dice_coefficient: 0.5030
# Epoch 13/100
# 100/100 [==============================] - 128s 1s/step - loss: 0.3529 - dice_coefficient: 0.5160 - val_loss: 0.3517 - val_dice_coefficient: 0.5203
# Epoch 14/100
# 100/100 [==============================] - 133s 1s/step - loss: 0.3363 - dice_coefficient: 0.5324 - val_loss: 0.3384 - val_dice_coefficient: 0.5340
# Epoch 15/100
# 100/100 [==============================] - 135s 1s/step - loss: 0.3201 - dice_coefficient: 0.5430 - val_loss: 0.3173 - val_dice_coefficient: 0.5520
# Epoch 16/100
# 100/100 [==============================] - 128s 1s/step - loss: 0.3102 - dice_coefficient: 0.5563 - val_loss: 0.3046 - val_dice_coefficient: 0.5481
# Epoch 17/100
# 100/100 [==============================] - 132s 1s/step - loss: 0.2959 - dice_coefficient: 0.5685 - val_loss: 0.2956 - val_dice_coefficient: 0.5956
# Epoch 18/100
# 100/100 [==============================] - 133s 1s/step - loss: 0.2821 - dice_coefficient: 0.5868 - val_loss: 0.2717 - val_dice_coefficient: 0.6042
# Epoch 19/100
# 100/100 [==============================] - 132s 1s/step - loss: 0.2598 - dice_coefficient: 0.6111 - val_loss: 0.2697 - val_dice_coefficient: 0.5919
# Epoch 20/100
# 100/100 [==============================] - 141s 1s/step - loss: 0.2557 - dice_coefficient: 0.6222 - val_loss: 0.2755 - val_dice_coefficient: 0.5887
# Epoch 21/100
# 100/100 [==============================] - 143s 1s/step - loss: 0.2458 - dice_coefficient: 0.6339 - val_loss: 0.2956 - val_dice_coefficient: 0.5203
# Epoch 22/100
# 100/100 [==============================] - 140s 1s/step - loss: 0.2370 - dice_coefficient: 0.6387 - val_loss: 0.2348 - val_dice_coefficient: 0.6345
# Epoch 23/100
# 100/100 [==============================] - 145s 1s/step - loss: 0.2408 - dice_coefficient: 0.6400 - val_loss: 0.2252 - val_dice_coefficient: 0.6653
# Epoch 24/100
# 100/100 [==============================] - 143s 1s/step - loss: 0.2240 - dice_coefficient: 0.6572 - val_loss: 0.2289 - val_dice_coefficient: 0.6529
# Epoch 25/100
# 100/100 [==============================] - 144s 1s/step - loss: 0.2199 - dice_coefficient: 0.6671 - val_loss: 0.2130 - val_dice_coefficient: 0.6747
# Epoch 26/100
# 100/100 [==============================] - 146s 1s/step - loss: 0.2090 - dice_coefficient: 0.6817 - val_loss: 0.2087 - val_dice_coefficient: 0.7061
# Epoch 27/100
# 100/100 [==============================] - 144s 1s/step - loss: 0.2113 - dice_coefficient: 0.6781 - val_loss: 0.2184 - val_dice_coefficient: 0.6381
# Epoch 28/100
# 100/100 [==============================] - 138s 1s/step - loss: 0.1985 - dice_coefficient: 0.6966 - val_loss: 0.1950 - val_dice_coefficient: 0.6956
# Epoch 29/100
# 100/100 [==============================] - 148s 1s/step - loss: 0.1986 - dice_coefficient: 0.7015 - val_loss: 0.1876 - val_dice_coefficient: 0.7243
# Epoch 30/100
# 100/100 [==============================] - 142s 1s/step - loss: 0.1864 - dice_coefficient: 0.7168 - val_loss: 0.1896 - val_dice_coefficient: 0.7158
# Epoch 31/100
# 100/100 [==============================] - 140s 1s/step - loss: 0.1873 - dice_coefficient: 0.7165 - val_loss: 0.1818 - val_dice_coefficient: 0.7237
# Epoch 32/100
# 100/100 [==============================] - 139s 1s/step - loss: 0.1826 - dice_coefficient: 0.7230 - val_loss: 0.1814 - val_dice_coefficient: 0.7252
# Epoch 33/100
# 100/100 [==============================] - 147s 1s/step - loss: 0.1853 - dice_coefficient: 0.7192 - val_loss: 0.1642 - val_dice_coefficient: 0.7429
# Epoch 34/100
# 100/100 [==============================] - 141s 1s/step - loss: 0.1690 - dice_coefficient: 0.7480 - val_loss: 0.1859 - val_dice_coefficient: 0.7199
# Epoch 35/100
# 100/100 [==============================] - 141s 1s/step - loss: 0.1780 - dice_coefficient: 0.7343 - val_loss: 0.1852 - val_dice_coefficient: 0.7159
# Epoch 36/100
# 100/100 [==============================] - 140s 1s/step - loss: 0.1688 - dice_coefficient: 0.7502 - val_loss: 0.2028 - val_dice_coefficient: 0.6828
# Epoch 37/100
# 100/100 [==============================] - 136s 1s/step - loss: 0.1741 - dice_coefficient: 0.7385 - val_loss: 0.1762 - val_dice_coefficient: 0.7384
# Epoch 38/100
# 100/100 [==============================] - 131s 1s/step - loss: 0.1618 - dice_coefficient: 0.7615 - val_loss: 0.1971 - val_dice_coefficient: 0.6738
# Epoch 39/100
# 100/100 [==============================] - 131s 1s/step - loss: 0.1751 - dice_coefficient: 0.7411 - val_loss: 0.1423 - val_dice_coefficient: 0.8126
# Epoch 40/100
# 100/100 [==============================] - 132s 1s/step - loss: 0.1600 - dice_coefficient: 0.7669 - val_loss: 0.1755 - val_dice_coefficient: 0.7039
# Epoch 41/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.1516 - dice_coefficient: 0.7792 - val_loss: 0.1655 - val_dice_coefficient: 0.7659
# Epoch 42/100
# 100/100 [==============================] - 128s 1s/step - loss: 0.1579 - dice_coefficient: 0.7728 - val_loss: 0.1547 - val_dice_coefficient: 0.7943
# Epoch 43/100
# 100/100 [==============================] - 136s 1s/step - loss: 0.1599 - dice_coefficient: 0.7669 - val_loss: 0.1754 - val_dice_coefficient: 0.7154
# Epoch 44/100
# 100/100 [==============================] - 140s 1s/step - loss: 0.1545 - dice_coefficient: 0.7760 - val_loss: 0.1736 - val_dice_coefficient: 0.7423
# Epoch 45/100
# 100/100 [==============================] - 127s 1s/step - loss: 0.1540 - dice_coefficient: 0.7779 - val_loss: 0.1487 - val_dice_coefficient: 0.7779
# Epoch 46/100
# 100/100 [==============================] - 131s 1s/step - loss: 0.1534 - dice_coefficient: 0.7800 - val_loss: 0.2185 - val_dice_coefficient: 0.6785
# Epoch 47/100
# 100/100 [==============================] - 118s 1s/step - loss: 0.1557 - dice_coefficient: 0.7757 - val_loss: 0.1289 - val_dice_coefficient: 0.8459
# Epoch 48/100
# 100/100 [==============================] - 129s 1s/step - loss: 0.1485 - dice_coefficient: 0.7865 - val_loss: 0.1612 - val_dice_coefficient: 0.7253
# Epoch 49/100
# 100/100 [==============================] - 131s 1s/step - loss: 0.1480 - dice_coefficient: 0.7873 - val_loss: 0.1556 - val_dice_coefficient: 0.7918
# Epoch 50/100
# 100/100 [==============================] - 136s 1s/step - loss: 0.1416 - dice_coefficient: 0.8027 - val_loss: 0.1740 - val_dice_coefficient: 0.7346
# Epoch 51/100
# 100/100 [==============================] - 128s 1s/step - loss: 0.1442 - dice_coefficient: 0.7949 - val_loss: 0.1687 - val_dice_coefficient: 0.7368
# Epoch 52/100
# 100/100 [==============================] - 133s 1s/step - loss: 0.1474 - dice_coefficient: 0.7921 - val_loss: 0.1765 - val_dice_coefficient: 0.7182
# Epoch 53/100
# 100/100 [==============================] - 135s 1s/step - loss: 0.1424 - dice_coefficient: 0.7954 - val_loss: 0.1310 - val_dice_coefficient: 0.8098
# Epoch 54/100
# 100/100 [==============================] - 123s 1s/step - loss: 0.1425 - dice_coefficient: 0.8001 - val_loss: 0.1363 - val_dice_coefficient: 0.7966
# Epoch 55/100
# 100/100 [==============================] - 125s 1s/step - loss: 0.1416 - dice_coefficient: 0.8042 - val_loss: 0.1548 - val_dice_coefficient: 0.6996
# Epoch 56/100
# 100/100 [==============================] - 121s 1s/step - loss: 0.1408 - dice_coefficient: 0.7978 - val_loss: 0.1655 - val_dice_coefficient: 0.7334
# Epoch 57/100
# 100/100 [==============================] - 113s 1s/step - loss: 0.1400 - dice_coefficient: 0.8040 - val_loss: 0.1568 - val_dice_coefficient: 0.7908
# Epoch 58/100
# 100/100 [==============================] - 109s 1s/step - loss: 0.1450 - dice_coefficient: 0.8019 - val_loss: 0.1345 - val_dice_coefficient: 0.8156
# Epoch 59/100
# 100/100 [==============================] - 117s 1s/step - loss: 0.1300 - dice_coefficient: 0.8251 - val_loss: 0.1696 - val_dice_coefficient: 0.7463
# Epoch 60/100
# 100/100 [==============================] - 121s 1s/step - loss: 0.1272 - dice_coefficient: 0.8295 - val_loss: 0.1781 - val_dice_coefficient: 0.7384
# Epoch 61/100
# 100/100 [==============================] - 110s 1s/step - loss: 0.1394 - dice_coefficient: 0.8034 - val_loss: 0.1055 - val_dice_coefficient: 0.8798
# Epoch 62/100
# 100/100 [==============================] - 109s 1s/step - loss: 0.1194 - dice_coefficient: 0.8470 - val_loss: 0.1610 - val_dice_coefficient: 0.7384
# Epoch 63/100
# 100/100 [==============================] - 118s 1s/step - loss: 0.1321 - dice_coefficient: 0.8184 - val_loss: 0.1115 - val_dice_coefficient: 0.8613
# Epoch 64/100
# 100/100 [==============================] - 124s 1s/step - loss: 0.1275 - dice_coefficient: 0.8318 - val_loss: 0.1437 - val_dice_coefficient: 0.8133
# Epoch 65/100
# 100/100 [==============================] - 127s 1s/step - loss: 0.1306 - dice_coefficient: 0.8219 - val_loss: 0.1340 - val_dice_coefficient: 0.8140
# Epoch 66/100
# 100/100 [==============================] - 124s 1s/step - loss: 0.1252 - dice_coefficient: 0.8322 - val_loss: 0.1413 - val_dice_coefficient: 0.8139
# Epoch 67/100
# 100/100 [==============================] - 114s 1s/step - loss: 0.1207 - dice_coefficient: 0.8414 - val_loss: 0.1165 - val_dice_coefficient: 0.8584
# Epoch 68/100
# 100/100 [==============================] - 112s 1s/step - loss: 0.1312 - dice_coefficient: 0.8282 - val_loss: 0.1292 - val_dice_coefficient: 0.8419
# Epoch 69/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.1221 - dice_coefficient: 0.8427 - val_loss: 0.1099 - val_dice_coefficient: 0.8583
# Epoch 70/100
# 100/100 [==============================] - 126s 1s/step - loss: 0.1242 - dice_coefficient: 0.8343 - val_loss: 0.1337 - val_dice_coefficient: 0.8220
# Epoch 71/100
# 100/100 [==============================] - 121s 1s/step - loss: 0.1249 - dice_coefficient: 0.8378 - val_loss: 0.1429 - val_dice_coefficient: 0.7989
# Epoch 72/100
# 100/100 [==============================] - 114s 1s/step - loss: 0.1214 - dice_coefficient: 0.8391 - val_loss: 0.1112 - val_dice_coefficient: 0.8672
# Epoch 73/100
# 100/100 [==============================] - 111s 1s/step - loss: 0.1250 - dice_coefficient: 0.8365 - val_loss: 0.1278 - val_dice_coefficient: 0.8175
# Epoch 74/100
# 100/100 [==============================] - 111s 1s/step - loss: 0.1238 - dice_coefficient: 0.8370 - val_loss: 0.1178 - val_dice_coefficient: 0.8389
# Epoch 75/100
# 100/100 [==============================] - 122s 1s/step - loss: 0.1216 - dice_coefficient: 0.8429 - val_loss: 0.1169 - val_dice_coefficient: 0.8501
# Epoch 76/100
# 100/100 [==============================] - 121s 1s/step - loss: 0.1217 - dice_coefficient: 0.8421 - val_loss: 0.1490 - val_dice_coefficient: 0.7749
# Epoch 77/100
# 100/100 [==============================] - 117s 1s/step - loss: 0.1219 - dice_coefficient: 0.8416 - val_loss: 0.1506 - val_dice_coefficient: 0.7735
# Epoch 78/100
# 100/100 [==============================] - 125s 1s/step - loss: 0.1176 - dice_coefficient: 0.8504 - val_loss: 0.1417 - val_dice_coefficient: 0.8080
# Epoch 79/100
# 100/100 [==============================] - 129s 1s/step - loss: 0.1234 - dice_coefficient: 0.8375 - val_loss: 0.1546 - val_dice_coefficient: 0.7482
# Epoch 80/100
# 100/100 [==============================] - 114s 1s/step - loss: 0.1270 - dice_coefficient: 0.8299 - val_loss: 0.1110 - val_dice_coefficient: 0.8694
# Epoch 81/100
# 100/100 [==============================] - 106s 1s/step - loss: 0.1208 - dice_coefficient: 0.8453 - val_loss: 0.1647 - val_dice_coefficient: 0.7481
# Epoch 82/100
# 100/100 [==============================] - 108s 1s/step - loss: 0.1243 - dice_coefficient: 0.8338 - val_loss: 0.1185 - val_dice_coefficient: 0.8691
# Epoch 83/100
# 100/100 [==============================] - 108s 1s/step - loss: 0.1155 - dice_coefficient: 0.8584 - val_loss: 0.1446 - val_dice_coefficient: 0.7930
# Epoch 84/100
# 100/100 [==============================] - 104s 1s/step - loss: 0.1186 - dice_coefficient: 0.8439 - val_loss: 0.1151 - val_dice_coefficient: 0.8563
# Epoch 85/100
# 100/100 [==============================] - 110s 1s/step - loss: 0.1185 - dice_coefficient: 0.8463 - val_loss: 0.1182 - val_dice_coefficient: 0.8545
# Epoch 86/100
# 100/100 [==============================] - 101s 1s/step - loss: 0.1249 - dice_coefficient: 0.8331 - val_loss: 0.1097 - val_dice_coefficient: 0.8847
# Epoch 87/100
# 100/100 [==============================] - 104s 1s/step - loss: 0.1244 - dice_coefficient: 0.8310 - val_loss: 0.1480 - val_dice_coefficient: 0.7351
# Epoch 88/100
# 100/100 [==============================] - 114s 1s/step - loss: 0.1264 - dice_coefficient: 0.8208 - val_loss: 0.1532 - val_dice_coefficient: 0.7356
# Epoch 89/100
# 100/100 [==============================] - 110s 1s/step - loss: 0.1185 - dice_coefficient: 0.8395 - val_loss: 0.1520 - val_dice_coefficient: 0.7661
# Epoch 90/100
# 100/100 [==============================] - 111s 1s/step - loss: 0.1209 - dice_coefficient: 0.8350 - val_loss: 0.1136 - val_dice_coefficient: 0.8454
# Epoch 91/100
# 100/100 [==============================] - 112s 1s/step - loss: 0.1152 - dice_coefficient: 0.8510 - val_loss: 0.1131 - val_dice_coefficient: 0.8710
# Epoch 92/100
# 100/100 [==============================] - 109s 1s/step - loss: 0.1134 - dice_coefficient: 0.8559 - val_loss: 0.1140 - val_dice_coefficient: 0.8690
# Epoch 93/100
# 100/100 [==============================] - 112s 1s/step - loss: 0.1164 - dice_coefficient: 0.8467 - val_loss: 0.1398 - val_dice_coefficient: 0.7872
# Epoch 94/100
# 100/100 [==============================] - 108s 1s/step - loss: 0.1184 - dice_coefficient: 0.8422 - val_loss: 0.1042 - val_dice_coefficient: 0.8810
# Epoch 95/100
# 100/100 [==============================] - 118s 1s/step - loss: 0.1193 - dice_coefficient: 0.8424 - val_loss: 0.1187 - val_dice_coefficient: 0.8366
# Epoch 96/100
# 100/100 [==============================] - 115s 1s/step - loss: 0.1230 - dice_coefficient: 0.8355 - val_loss: 0.1274 - val_dice_coefficient: 0.8486
# Epoch 97/100
# 100/100 [==============================] - 127s 1s/step - loss: 0.1129 - dice_coefficient: 0.8640 - val_loss: 0.1132 - val_dice_coefficient: 0.8762
# Epoch 98/100
# 100/100 [==============================] - 125s 1s/step - loss: 0.1189 - dice_coefficient: 0.8456 - val_loss: 0.1530 - val_dice_coefficient: 0.7569
# Epoch 99/100
# 100/100 [==============================] - 115s 1s/step - loss: 0.1163 - dice_coefficient: 0.8514 - val_loss: 0.1359 - val_dice_coefficient: 0.8188
# Epoch 100/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.1115 - dice_coefficient: 0.8621 - val_loss: 0.1241 - val_dice_coefficient: 0.8320

# %%
#Sample n MRI images and Predict
predict_random(7)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# ---------------------------------------------------
#  Loading MRI Test Data(Random) and Model from Disk
# ---------------------------------------------------
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   # Remove the CWD from sys.path while we load stuff.
# 100%|██████████| 7/7 [00:08<00:00,  1.25s/it]
# Dice Coefficient: 0.917392
# Dice Coefficient: 0.877996
# Dice Coefficient: 0.810151
# Dice Coefficient: 0.882806
# Dice Coefficient: 0.929277
# Dice Coefficient: 0.907660
# Dice Coefficient: 0.925251
# Mean Dice Coeff=0.892933, Std Dice Coeff=0.038469
